# %% [markdown]
# # NAME:PRATIK PATIL
# # 19MAI0048

# %%
from nltk.corpus import indian              #importing corpus

# %%
indian.fileids()                           #getting fields in the corpus
# Out:
# ['bangla.pos', 'hindi.pos', 'marathi.pos', 'telugu.pos']

# %%
for f in indian.fileids():               #getting the length
    print(f)
    print(len(indian.raw(f)))
# Out:
# bangla.pos
# 118283
# hindi.pos
# 103087
# marathi.pos
# 229853
# telugu.pos
# 138273

# %%
marathi=indian.sents('marathi.pos')                    #reading marathi corpus

# %%
marathi
# Out:
# [["''", 'सनातनवाद्यांनी', 'व', 'प्रतिगाम्यांनी', 'समाज', 'रसातळाला', 'नेला', 'असताना', 'या', 'अंधारात', 'बाळशास्त्री', 'जांभेकर', 'यांनी', "'दर्पण'च्या", 'माध्यमातून', 'पहिली', 'ज्ञानज्योत', 'तेववली', ',', "''", 'असे', 'प्रतिपादन', 'नटसम्राट', 'प्रभाकर', 'पणशीकर', 'यांनी', 'केले', '.'], ['दर्पणकार', 'बाळशास्त्री', 'जांभेकर', 'यांच्या', '१९५व्या', 'जयंतीनिमित्त', 'महाराष्ट्र', 'संपादक', 'परिषद', 'व', 'सिंधुदुर्ग', 'जिल्हा', 'मराठी', 'पत्रकार', 'संघाच्या', 'वतीने', 'तसेच', 'महाराष्ट्र', 'जर्नलिस्ट', 'फाउंडेशन', 'व', 'महाराष्ट्र', 'ग्रामीण', 'पत्रकार', 'संघाच्या', 'सहभागाने', 'अभिवादन', 'कार्यक्रम', 'आयोजित', 'केला', 'होता', '.'], ...]

# %%
for msen in marathi:                        #display each word in corupus
    print(msen)
# Out:
# ["''", 'सनातनवाद्यांनी', 'व', 'प्रतिगाम्यांनी', 'समाज', 'रसातळाला', 'नेला', 'असताना', 'या', 'अंधारात', 'बाळशास्त्री', 'जांभेकर', 'यांनी', "'दर्पण'च्या", 'माध्यमातून', 'पहिली', 'ज्ञानज्योत', 'तेववली', ',', "''", 'असे', 'प्रतिपादन', 'नटसम्राट', 'प्रभाकर', 'पणशीकर', 'यांनी', 'केले', '.']
# ['दर्पणकार', 'बाळशास्त्री', 'जांभेकर', 'यांच्या', '१९५व्या', 'जयंतीनिमित्त', 'महाराष्ट्र', 'संपादक', 'परिषद', 'व', 'सिंधुदुर्ग', 'जिल्हा', 'मराठी', 'पत्रकार', 'संघाच्या', 'वतीने', 'तसेच', 'महाराष्ट्र', 'जर्नलिस्ट', 'फाउंडेशन', 'व', 'महाराष्ट्र', 'ग्रामीण', 'पत्रकार', 'संघाच्या', 'सहभागाने', 'अभिवादन', 'कार्यक्रम', 'आयोजित', 'केला', 'होता', '.']
# ['महाराष्ट्र', 'संपादक', 'परिषदेचे', 'कार्याध्यक्ष', 'यशवंत', 'पाध्ये', ',', 'जिल्हा', 'पत्रकार', 'संघाचे', 'अध्यक्ष', 'शशी', 'सावंत', 'यावेळी', 'उपस्थित', 'होते', '.']
# ...

# %%
mpos=indian.tagged_sents('marathi.pos')

# %%
for sent in mpos:
    print(sent)
# Out:
# [("''", 'SYM'), ('सनातनवाद्यांनी', 'NN'), ('व', 'CC'), ('प्रतिगाम्यांनी', 'NN'), ('समाज', 'NN'), ('रसातळाला', 'NN'), ('नेला', 'VM'), ('असताना', 'VAUX'), ('या', 'DEM'), ('अंधारात', 'NN'), ('बाळशास्त्री', 'NNPC'), ('जांभेकर', 'NNP'), ('यांनी', 'PRP'), ("'दर्पण'च्या", 'NNP'), ('माध्यमातून', 'NN'), ('पहिली', 'QO'), ('ज्ञानज्योत', 'NN'), ('तेववली', 'VM'), (',', 'SYM'), ("''", 'SYM'), ('असे', 'DEM'), ('प्रतिपादन', 'NN'), ('नटसम्राट', 'NNPC'), ('प्रभाकर', 'NNPC'), ('पणशीकर', 'NNP'), ('यांनी', 'PRP'), ('केले', 'VM'), ('.', 'SYM')]
# ...

# %%
#reading a marathi text 
new_mar="""शिवाजी विद्यापीठाच्या राज्यशास्त्र विभागाच्या वतीने स्त्री हक्क या विषयावर आयोजित कार्यशाळेच्या उद्‌घाटनप्रसंगी त्या बोलत होत्या . " 
मानवी हक्क आणि स्त्री हक्क " असा त्यांच्या व्याख्यानाचा विषय होता . अध्यक्षस्थानी कुलगुरू डॉ. माणिकराव साळुंखे होते . 
"मिळून साऱ्या जणी"च्या संपादिका विद्या बाळ प्रमुख उपस्थित होत्या . विद्यापीठाच्या मानव्यशास्त्र सभागृहात कार्यक्रम झाला . प्रा. भावे म्हणाल्या 
, " मानव या संकल्पनेत स्त्रीचा समावेश आहे . त्यामुळे मानवी हक्क आणि स्त्रियांचे हक्क वेगळे नाहीत ; पण पुरुषसत्ताक समाजव्यवस्थेमुळे स्त्रीच्या हक्कांची 
पायमल्ली होते . विशिष्ट समुदायांच्या रूढी-परंपरांमुळे स्त्रियांचे हक्क हिरावले . त्याला तत्त्वज्ञान व संस्कृतीचे कुंपण घालण्यात आले . हे कुंपण आजही स्त्रिया 
अनुभवतात . जातपंचायतींचा बडगा आजही अनेक समाजांमध्ये दिसत आहे . नोकरीच्या ठिकाणी होणारे लैगिंक शोषण व मानसिक छळ , गरोदरपणात रजा न 
तत्कालीन आदिवासींना ते अवशेष आणि लांबट हाडे ( जीवाश्‍म ) सुरवातीला चक्क ड्रॅगन किंवा अवाढव्य असू शकेल , असे त्यांना वाटले नसावे ."""

# %%
from nltk.tokenize import word_tokenize          #impoerting tockenizer

# %%
#line1 = marathi1                               #tockenizing all the words in the text 
Marathi_token = word_tokenize(new_mar)
print(Marathi_token)
#arathi_tokens
# Out:
# ['शिवाजी', 'विद्यापीठाच्या', 'राज्यशास्त्र', 'विभागाच्या', 'वतीने', 'स्त्री', 'हक्क', 'या', 'विषयावर', 'आयोजित', 'कार्यशाळेच्या', 'उद्\u200cघाटनप्रसंगी', 'त्या', 'बोलत', 'होत्या', '.', '``', 'मानवी', 'हक्क', 'आणि', 'स्त्री', 'हक्क', '``', 'असा', 'त्यांच्या', 'व्याख्यानाचा', 'विषय', 'होता', '.', 'अध्यक्षस्थानी', 'कुलगुरू', 'डॉ', '.', 'माणिकराव', 'साळुंखे', 'होते', '.', '``', 'मिळून', 'साऱ्या', 'जणी', "''", 'च्या', 'संपादिका', 'विद्या', 'बाळ', 'प्रमुख', 'उपस्थित', 'होत्या', '.', 'विद्यापीठाच्या', 'मानव्यशास्त्र', 'सभागृहात', 'कार्यक्रम', 'झाला', '.', 'प्रा', '.', 'भावे', 'म्हणाल्या', ',', '``', 'मानव', 'या', 'संकल्पनेत', 'स्त्रीचा', 'समावेश', 'आहे', '.', 'त्यामुळे', 'मानवी', 'हक्क', 'आणि', 'स्त्रियांचे', 'हक्क', 'वेगळे', 'नाहीत', ';', 'पण', 'पुरुषसत्ताक', 'समाजव्यवस्थेमुळे', 'स्त्रीच्या', 'हक्कांची', 'पायमल्ली', 'होते', '.', 'विशिष्ट', 'समुदायांच्या', 'रूढी-परंपरांमुळे', 'स्त्रियांचे', 'हक्क', 'हिरावले', '.', 'त्याला', 'तत्त्वज्ञान', 'व', 'संस्कृतीचे', 'कुंपण', 'घालण्यात', 'आले', '.', 
# ...

# %%
len(new_mar)                                               #lenghth of all words
# Out:
# 5085

# %%
from nltk.probability import FreqDist                      #import library for frequency distribution

# %%
fdist = FreqDist()

# %%
for words in new_mar:                                      #fetching each of the words in corpus 
    fdist[words.lower()]+=1
fdist
# Out:
# FreqDist({' ': 798, 'ा': 559, '्': 325, 'र': 227, 'त': 215, 'े': 212, 'य': 199, 'ी': 162, 'स': 152, 'व': 135, ...})

# %%
fdist_high_freq = fdist.most_common(9)                  #fetching the highest frequency 
fdist_high_freq
# Out:
# [(' ', 798),
#  ('ा', 559),
#  ('्', 325),
#  ('र', 227),
#  ('त', 215),
#  ('े', 212),
#  ('य', 199),
#  ('ी', 162),
#  ('स', 152)]
