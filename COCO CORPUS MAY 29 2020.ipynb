# %%
#Task 1 Demonstrating COCA
#HW: Explore COCA for 3 different search strings (one personality) or all 3 can be names too
#under coca 3 januras

# %% [markdown]
# ## Using Porter Stemmer

# %%
#Task 2 Stemming:
import nltk
from nltk.stem import PorterStemmer
stemmerporter = PorterStemmer()
stemmerporter.stem('megabyte') #wrong stemming
#read about porter stemmer
# Out:
# 'megabyt'

# %%
stemmerporter.stem('waiting')
# Out:
# 'wait'

# %%
stemmerporter.stem('holiness')
# Out:
# 'holi'

# %%
stemmerporter.stem('beautiful')
# Out:
# 'beauti'

# %%
stemmerporter.stem('cleanliness')
# Out:
# 'cleanli'

# %% [markdown]
# ## Tokenization of a sentence and applying porter stemmer to find stem words

# %%
import nltk
from nltk.stem.porter import *

porterStemmer = PorterStemmer()

sentence = "Provision Maximum multiply owed caring on go gone going was this"
wordList = nltk.word_tokenize(sentence)

stemWords = [porterStemmer.stem(word) for word in wordList]

print(' '.join(stemWords))
# Out:
# provis maximum multipli owe care on go gone go wa thi

# %% [markdown]
# ## Applying LancasterStemmer

# %%
#using another stemmer 
#type 2 LancasterStemmer 
from nltk.stem import LancasterStemmer
stemmerLan = LancasterStemmer()
stemmerLan.stem('happiness')
# Out:
# 'happy'

# %% [markdown]
# ###  Tokenization of a sentence and applying LancasterStemmer to find stem words

# %%
#tockenization of a sentence and then using lancaster stemmer 
import nltk
from nltk.stem.lancaster import *

lancasterStemmer = LancasterStemmer()

sentence = "Provision Maximum multiply owed caring on go gone going was this"
wordList = nltk.word_tokenize(sentence)

stemWords = [lancasterStemmer.stem(word) for word in wordList]

print(' '.join(stemWords))
# Out:
# provid maxim multiply ow car on go gon going was thi

# %% [markdown]
# ## Regex Stemmer

# %%
#Regexstemmer can be used 
import nltk
from nltk.stem import RegexpStemmer
stemmerregexp = RegexpStemmer('ing')
stemmerregexp.stem('driving')
# Out:
# 'driv'

# %% [markdown]
# ## SnowballStemmer Multilingial

# %%
#multilingual stemma
from nltk.stem import SnowballStemmer
SnowballStemmer.languages
frenchstemmer = SnowballStemmer('french')
frenchstemmer.stem('manges')
# Out:
# 'mang'

# %%
#HW 3 Demonstrate snownball stemming in Hindi / Tamil / french optional

# %%
#Task 3 Stemming a paragraph
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
example = "He is a lazy these days"
example = [stemmer.stem(token) for token in example.split(" ")]
print(" ".join(example))
# Out:
# He is a lazi these day

# %% [markdown]
# ## Using Wordnet Lemmitizer

# %% [markdown]
# ####  find the corresponding tag in WordNet and then use the lemmatizer to lemmatize the token based on the tag

# %%
#Task 4: Lemmatizer
# we use wordnet lemmitizer here 
#
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("cacti"))
# Out:
# cactus

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
lemmatizer=WordNetLemmatizer()
input_str="been had done languages cities mice"
input_str=word_tokenize(input_str)
for word in input_str:
    print(lemmatizer.lemmatize(word))
# Out:
# been
# had
# done
# language
# city
# mouse

# %%
print(lemmatizer.lemmatize("better"))
# Out:
# better

# %%
print(lemmatizer.lemmatize("better", pos='a'))
# Out:
# good

# %%
print(lemmatizer.lemmatize("I am loving it"))
# Out:
# I am loving it

# %%
print(lemmatizer.lemmatize("Am",pos = 'v'))
# Out:
# Am

# %% [markdown]
# ## Chinese Segmentation using JIEBA

# %%
#TAsk 5 Chinese Segmentation using JIEBA
import jieba
seg = jieba.cut("你在做什么", cut_all = True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\hp\AppData\Local\Temp\jieba.cache
# Loading model cost 0.766 seconds.
# Prefix dict has been built successfully.
# 你 在 做 什么

# %%
#hanlp and stanford nlp read and can use them also and experiment them also
# Task 6: Basic Text Processing Pipeline
import nltk
sent = "Become an expert in NLP!"
words = nltk.word_tokenize(sent)
print(words)
# Out:
# ['Become', 'an', 'expert', 'in', 'NLP', '!']

# %% [markdown]
# ## Tockenization

# %%
texts = """After assuming control of government, Caesar began a program of social and governmental reforms, including the creation of the Julian calendar. He gave citizenship to many residents of far regions of the Roman Republic. He initiated land reform and support for veterans. He centralized the bureaucracy of the Republic and was eventually proclaimed "dictator for life"""
import nltk
for text in texts:
    sentences = nltk.sent_tokenize(texts)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        print(words)
# Out:
# ['After', 'assuming', 'control', 'of', 'government', ',', 'Caesar', 'began', 'a', 'program', 'of', 'social', 'and', 'governmental', 'reforms', ',', 'including', 'the', 'creation', 'of', 'the', 'Julian', 'calendar', '.']
# ['He', 'gave', 'citizenship', 'to', 'many', 'residents', 'of', 'far', 'regions', 'of', 'the', 'Roman', 'Republic', '.']
# ['He', 'initiated', 'land', 'reform', 'and', 'support', 'for', 'veterans', '.']
# ['He', 'centralized', 'the', 'bureaucracy', 'of', 'the', 'Republic', 'and', 'was', 'eventually', 'proclaimed', '``', 'dictator', 'for', 'life']
# ['After', 'assuming', 'control', 'of', 'government', ',', 'Caesar', 'began', 'a', 'program', 'of', 'social', 'and', 'governmental', 'reforms', ',', 'including', 'the', 'creation', 'of', 'the', 'Julian', 'calendar', '.']
# ['He', 'gave', 'citizenship', 'to', 'many', 'residents', 'of', 'far', 'regions', 'of', 'the', 'Roman', 'Republic', '.']
# ['He', 'initiated', 'land', 'reform', 'and', 'support', 'for', 'veterans', '.']
# ...

# %% [markdown]
# ## Part of Speech Tagging

# %%
tagged = nltk.pos_tag(words)
print(tagged)
# Out:
# [('He', 'PRP'), ('centralized', 'VBD'), ('the', 'DT'), ('bureaucracy', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Republic', 'NNP'), ('and', 'CC'), ('was', 'VBD'), ('eventually', 'RB'), ('proclaimed', 'VBN'), ('``', '``'), ('dictator', 'NN'), ('for', 'IN'), ('life', 'NN')]
