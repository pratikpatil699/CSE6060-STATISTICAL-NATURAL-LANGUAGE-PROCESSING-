# %% [markdown]
# # PRATIK PATIL
# # 19MAI0048

# %%
import nltk
from nltk import word_tokenize

# %%
#importing from website
from urllib import request 
url = "http://www.gutenberg.org/files/62303/62303-0.txt"
response = request.urlopen(url) #response is received from the given url
rawtext = response.read().decode('utf8') # decodes a string, previously encoded with the utf8_encode() function, back to ISO-8859-1.
type(rawtext) #shows the type of text
# Out:
# str

# %%
len(rawtext) #length of the text
# Out:
# 251438

# %%
rawtext[:75]
# Out:
# '\ufeffThe Project Gutenberg eBook, A Winter of Content, by Laura Lee Davidson\r\n\r'

# %%
#tokenize the string (raw text)
tokens = word_tokenize(rawtext)
type(tokens)
# Out:
# list

# %%
len(tokens) #length of the tokens which is being reduced fron the length of the raw text
# Out:
# 52177

# %%
text = nltk.Text(tokens) #here the nltk text is created
type(text)
# Out:
# nltk.text.Text

# %%
#concordance of particular word from the text corpus
text.concordance('delicious') #finding some concordance for word odor
# Out:
# Displaying 1 of 1 matches:
#  of a lake , and I shall smell the delicious odor of fresh-cut maple , beech ,

# %%
#Install Text Blob Module which helps for part of Speech tagging
#pip install -U textblob
#python -m textblob.download_corpora

from textblob import TextBlob
blob_object = TextBlob(rawtext) #raw text must be given not tokens
print(blob_object.tags)
# Out:
# [('\ufeffThe', 'NN'), ('Project', 'NNP'), ('Gutenberg', 'NNP'), ('eBook', 'NN'), ('A', 'NNP'), ('Winter', 'NNP'), ('of', 'IN'), ('Content', 'NNP'), ('by', 'IN'), ('Laura', 'NNP'), ('Lee', 'NNP'), ('Davidson', 'NNP'), ('This', 'DT'), ('eBook', 'NN'), ('is', 'VBZ'), ('for', 'IN'), ('the', 'DT'), ('use', 'NN'), ('of', 'IN'), ('anyone', 'NN'), ('anywhere', 'RB'), ('in', 'IN'), ('the', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('and', 'CC'), ('most', 'JJS'), ('other', 'JJ'), ('parts', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('world', 'NN'), ('at', 'IN'), ('no', 'DT'), ('cost', 'NN'), ('and', 'CC'), ('with', 'IN'), ('almost', 'RB'), ('no', 'DT'), ('restrictions', 'NNS'), ('whatsoever', 'RB'), ('You', 'PRP'), ('may', 'MD'), ('copy', 'VB'), ('it', 'PRP'), ('give', 'VB'), ('it', 'PRP'), ('away', 'RB'), ('or', 'CC'), ('re-use', 'VB'), ('it', 'PRP'), ('under', 'IN'), ('the', 'DT'), ('terms', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Project', 'NNP'), ('Gutenberg', 'NNP'), ('License', 'NNP'), ('included', 'VBD'), ('with', 'IN'), ('this', 'DT'), ('eBook', 'NN'), ('or', 'CC'), ('online', 'NN'), ('at', 'IN'), ('www.gutenberg.org', 'NN'), ('If', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('not', 'RB'), ('located', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('you', 'PRP'), ("'ll", 'MD'), ('have', 'VB'), ('to', 'TO'), ('check', 'VB'), ('the', 'DT'), ('laws', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('country', 'NN'), ('where', 'WRB'), ('you', 'PRP'), ('are', 'VBP'), ('located', 'VBN'), ('before', 'IN'), ('using', 'VBG'), ('this', 'DT'), ('ebook', 'NN'), ('Title', 'NN'), ('A', 'DT'), ('Winter', 'NN'), ('of', 'IN'), ('Content', 'NNP'), ('Author', 'NNP'), ('Laura', 'NNP'), ('Lee', 'NNP'), ('Davidson', 'NNP'), ('Release', 'NNP'), ('Date', 'NNP'), ('June', 'NNP'), ('2', 'CD'), ('2020', 'CD'), ('[', 'NNP'), ('eBook', 'VBD'), ('62303', 'CD'), (']', 'JJ'), ('Language', 'NN'), ('English', 'JJ'), ('Character', 'NNP'), ('set', 'VBD'), ('encoding', 'VBG'), ('UTF-8', 'JJ'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('START', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('PROJECT', 'NNP'), ('GUTENBERG', 'NNP'), ('EBOOK', 'NNP'), ('A', 'NNP'), ('WINTER', 'NNP'), ('OF', 'NNP'), ('CONTENT', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('This', 'DT'), ('text', 'NN'), ('was', 'VBD'), ('transcribed', 'VBN'), ('by', 'IN'), ('Les', 'NNP'), ('Bowler', 'NNP'), ('[', 'NNP'), ('Picture', 'NN'), ('Book', 'NNP'), ('cover', 'NN'), (']', 'NNP'), ('[', 'JJ'), ('Picture', 'NN'), ('“', 'CC'), ('Through', 'IN'), ('patches', 'NNS'), ('of', 'IN'), ('snow', 'JJ'), ('”', 'NNP'), (']', 'VBZ'), ('A', 'NNP'), ('Winter', 'NNP'), ('of', 'IN'), ('Content', 'NNP'), ('By', 'IN'), ('LAURA', 'NNP'), ('LEE', 'NNP'), ('DAVIDSON', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('“', 'RB'), ('Now', 'RB'), ('there', 'EX'), ('is', 'VBZ'), ('a', 'DT'), ('rocky', 'JJ'), ('isle', 'NN'), ('in', 'IN'), ('the', 'DT'), ('mid', 'NN'), ('sea', 'NN'), ('midway', 'NN'), ('between', 'IN'), ('Ithaca', 'NNP'), ('and', 'CC'), ('rocky', 'JJ'), ('Samos', 'NNP'), ('Asteris', 'NNP'), ('a', 'DT'), ('little', 'JJ'), ('isle.', 'JJ'), ('”', 'IN'), ('The', 'DT'), ('Odyssey', 'NNP'), ('of', 'IN'), ('Homer', 'NNP'), ('Translated', 'VBN'), ('by', 'IN'), ('S.', 'NNP'), ('S.', 'NNP'), ('Butcher', 'NNP'), ('and', 'CC'), ('Andrew', 'NNP'), ('Lang', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('[', 'JJ'), ('Picture', 'NN'), ('Decorate', 'NNP'), ('graphic', 'JJ'), (']', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'VBD'), ('THE', 'NNP'), ('ABINGDON', 'NNP'), ('PRESS', 'NNP'), ('NEW', 'NNP'), ('YORK', 'NNP'), ('CINCINNATI', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('Copyright', 'NNP'), ('1922', 'CD'), ('by', 'IN'), ('LAURA', 'NNP'), ('LEE', 'NNP'), ('DAVIDSON', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP'), ('Printed', 'NNP'), ('in', 'IN'), ('the', 'DT'), ...

# %%
#stemming
from nltk.stem import LancasterStemmer
Lancaster = LancasterStemmer()
stem_sentence = []
def stemsentence(text):
    for word in tokens:
        stem_sentence.append(Lancaster.stem(word))
        stem_sentence.append(" ")
    return "".join(stem_sentence)
x = stemsentence(text)
print(x)
# Out:
